# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x12b874b90>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x12b874050>
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[2], line 8
#       4 model_endpoint = "accounts/fireworks/models/gpt-oss-20b"
#       6 llm = ChatFireworks(model=model_endpoint)
# ----> 8 response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
#       9 print(response.content)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1201, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1192 @override
#    1193 def generate_prompt(
#    1194     self,
#    (...)   1198     **kwargs: Any,
#    1199 ) -> LLMResult:
#    1200     prompt_messages = [p.to_messages() for p in prompts]
# -> 1201     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1010, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1007 for i, m in enumerate(input_messages):
#    1008     try:
#    1009         results.append(
# -> 1010             self._generate_with_cache(
#    1011                 m,
#    1012                 stop=stop,
#    1013                 run_manager=run_managers[i] if run_managers else None,
#    1014                 **kwargs,
#    1015             )
#    1016         )
#    1017     except BaseException as e:
#    1018         if run_managers:
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1313, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1311     result = generate_from_stream(iter(chunks))
#    1312 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1313     result = self._generate(
#    1314         messages, stop=stop, run_manager=run_manager, **kwargs
#    1315     )
#    1316 else:
#    1317     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/langchain_fireworks/chat_models.py:536, in ChatFireworks._generate(self, messages, stop, run_manager, stream, **kwargs)
#     530 message_dicts, params = self._create_message_dicts(messages, stop)
#     531 params = {
#     532     **params,
#     533     **({"stream": stream} if stream is not None else {}),
#     534     **kwargs,
#     535 }
# --> 536 response = self.client.create(messages=message_dicts, **params)
#     537 return self._create_chat_result(response)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/chat_completion.py:41, in ChatCompletionV2.create(self, model, prompt_or_messages, request_timeout, stream, extra_headers, **kwargs)
#      32 def create(
#      33     self,
#      34     model,
#    (...)     39     **kwargs,
#      40 ):
# ---> 41     return super().create(
#      42         model,
#      43         prompt_or_messages,
#      44         request_timeout,
#      45         stream=stream,
#      46         client=self._client,
#      47         extra_headers=extra_headers,
#      48         **self._validate_kwargs(kwargs),
#      49     )
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/base_completion.py:81, in BaseCompletion.create(cls, model, prompt_or_messages, request_timeout, stream, client, extra_headers, **kwargs)
#      73     return cls._create_streaming(
#      74         model,
#      75         request_timeout,
#    (...)     78         **kwargs,
#      79     )
#      80 else:
# ---> 81     return cls._create_non_streaming(
#      82         model,
#      83         request_timeout,
#      84         client=client,
#      85         extra_headers=extra_headers,
#      86         **kwargs,
#      87     )
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/base_completion.py:180, in BaseCompletion._create_non_streaming(cls, model, request_timeout, client, extra_headers, **kwargs)
#     178 client = client or FireworksClient(request_timeout=request_timeout)
#     179 data = {"model": model, "stream": False, **kwargs}
# --> 180 response = client.post_request_non_streaming(
#     181     f"{client.base_url}/{cls.endpoint}",
#     182     data=data,
#     183     extra_headers=extra_headers,
#     184 )
#     185 return cls.response_class(**response)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/fireworks/client/api_client.py:256, in FireworksClient.post_request_non_streaming(self, url, data, extra_headers)
#     240 def post_request_non_streaming(
#     241     self,
#     242     url: str,
#     243     data: Optional[Dict[str, Any]] = None,
#     244     extra_headers: Optional[Dict[str, str]] = None,
#     245 ) -> Dict[str, Any]:
#     246     """Make a non-streaming POST request.
#     247
#     248     Args:
#    (...)    254         JSON response data as a dictionary.
#     255     """
# --> 256     response = self._client.post(url, json=data, headers=self._build_headers(extra_headers))
#     257     self._error_handling(response)
#     258     return response.json()
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_client.py:1144, in Client.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1123 def post(
#    1124     self,
#    1125     url: URL | str,
#    (...)   1137     extensions: RequestExtensions | None = None,
#    1138 ) -> Response:
#    1139     """
#    1140     Send a `POST` request.
#    1141
#    1142     **Parameters**: See `httpx.request`.
#    1143     """
# -> 1144     return self.request(
#    1145         "POST",
#    1146         url,
#    1147         content=content,
#    1148         data=data,
#    1149         files=files,
#    1150         json=json,
#    1151         params=params,
#    1152         headers=headers,
#    1153         cookies=cookies,
#    1154         auth=auth,
#    1155         follow_redirects=follow_redirects,
#    1156         timeout=timeout,
#    1157         extensions=extensions,
#    1158     )
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File ~/Development/aim/code/AIE9/16_LLM_Servers/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 20: If a wood‑chuck could chuck wood at all, folklore says—“as m...
# Response 24: A woodchuck would chuck about as much wood as could fit in i...
# Response 16: If a woodchuck could actually chuck wood, the folklore (and ...
# Response 3: A humorously accepted answer is that a woodchuck could chuck...
# Response 23: The classic answer to this tongue‑twister is, “**About 700 p...
# Response 5: The classic tongue‑twister leaves a lot to the imagination, ...
# Response 1: The classic answer to the tongue‑twister is that a woodchuck...
# Response 14: The classic answer is that a wood‑chuck wouldn’t actually ge...
# Response 6: The classic tongue‑twister never requires a precise science‑...
# Response 4: In the classic tongue‑twister, the folk answer is that a woo...
# Response 22: It’s a tongue‑twister, not a math problem, so the “answer” i...
# Response 8: The classic answer to the tongue‑twister is: **“A woodchuck ...
# Response 21: If a wood chuck could chuck wood, the old tongue‑twister doe...
# Response 11: The tongue‑twisters around the world never quite tell us the...
# Response 15: **Answer:**
#
# According to a 1988 study by wildlife biologist...
# Response 19: A woodchuck (aka a groundhog) would chuck roughly **700 poun...
# Response 9: 🎶 **“How Much Wood?” – The Legendary Woodchuck Riddle**
#
# > “...
# Response 2: It’s a classic tongue‑twister rather than a hard science que...
# Response 7: They never really did—it's a tongue‑twister, not a real phys...
# Response 17: It’s a classic tongue‑twister, not a literal fact, but the m...
# Response 12: Ah, the great mill‑ennial rhyme that never quite stopped the...
# Response 13: **Short answer:**
# > “A wood‑chuck would chuck… **about 700...
# Response 18: The classic tongue‑twister doesn’t really have a mathematica...
# Response 10: **The classic answer**
# > *“He would chuck as much wood as ...
